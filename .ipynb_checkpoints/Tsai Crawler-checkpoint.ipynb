# %%
access_token = "CAACEdEose0cBAGwIm022ZCAIq0ZCep3dDu5SXDs5WgvnO2fh6OIGm40fLNOB7sj4Os8XZCvh9lu1u9pQC2gayvUxnAtL8mH31pPjEn7DaVVSmZBzUPwiKb6G6imk4yUslQyG7KGt0GuFTFCyatZCaWzN92fEB2aSopkqnZBi3bhOdKFHOaZCWXK6SjXQipmycZC80ZB9Dd7h2YQZDZD"

# %%
# Install RCurl
# install.packages("RCurl", repos='http://cran.us.r-project.org')
# install.packages("rjson", repos="http://cran.us.r-project.org")
install.packages("RJSONIO", repos="http://cran.us.r-project.org")
# Out:
# The downloaded binary packages are in
# 	/var/folders/nj/mmt3l4jn1_zgg7b7ft_hk4nc0000gq/T//RtmpZVo5cZ/downloaded_packages

# %%
# Load RCurl Library
library(RCurl)
# library(rjson)
library(RJSONIO)
# library(jsonlite)
# Out:
# Loading required package: bitops

# %%
# help(sprintf)
# A wrapper for the C function sprintf, that returns 
# a character vector containing a formatted combination of text and variable values.

query_fields = "posts.limit(1){comments{comments{like_count,message},comment_count,like_count,message},message}"

query_id = "EggplantEgg"
query_id = "DoctorKoWJ"

f_url <-sprintf( "https://graph.facebook.com/%s?access_token=%s&fields=%s", query_id, access_token, query_fields )

f_url
# Out:
# Error in sprintf("https://graph.facebook.com/%s?access_token=%s&fields=%s", : 找不到物件 'access_token'
# Error in eval(expr, envir, enclos): 找不到物件 'f_url'

# %%
# connect = fromJSON(connect)
# connect$posts
# "data" %in% connect$posts
"data" %in% names(connect$posts)
connect$posts$data[[1]]$comments$paging["haha"]
# Out:
# [1] TRUE
# $<NA>
# NULL

# %%
# the website I'm reading
connect <- getURL(f_url)
# connect
connect$posts
# Out:
# [1] "{\"posts\":{\"data\":[{\"message\":\"謝謝苗栗鄉親及團隊的努力。雖然兩位立委未能選上，但得票率超過45%，選票成長僅次於台北市，是全國第二，而且 吳宜臻得到的選票比我還多！未來我們在苗栗要實現「台三線國家終浪漫大道」計畫，我們執政會不分黨派、不分藍綠，和苗栗縣政府一起努力，照顧每一位苗栗鄉親。\n\n吳宜臻是我們的青壯世代，願意投入最艱困的選區，選輸後也不會放棄，會繼續在這裡努力，這就是我們民進黨的精神，失敗了沒關係，眼淚擦乾再繼續。在苗栗，我們會一直努力，一直努力到獲得鄉親認同的那一天。\",\"id\":\"46251501064_10153140471286065\",\"created_time\":\"2016-01-26T01:00:01+0000\",\"comments\":{\"data\":[{\"comment_count\":14,\"like_count\":25,\"message\":\"http://news.ltn.com.tw/news/politics/breakingnews/1177749\",\"id\":\"10153140471286065_10153141180321065\",\"comments\":{\"data\":[{\"like_count\":1,\"message\":\"若完全沒事，蔡 必須下台負責\",\"id\":\"10153140471286065_10153141184866065\"},{\"like_count\":1,\"message\":\"合理吧？！這才叫改革嘛！\",\"id\":\"10153140471286065_10153141185391065\"},{\"like_count\":5,\"message\":\"史上最打臉國民黨影片，\n豬一樣的團隊。\n\nhttp://m.appledaily.com.tw/realtimenews/article/politics/20150924/697994/\",\"id\":\"10153140471286065_10153141190161065\"},{\"like_count\":1,\"message\":\"這才叫打臉啦\n只會在臉書發文治國⋯\n叫你們提前
# ...

# %% [markdown]
# <h3> Regex to replace '//"'</h3>
# The reason that you need four backslashes to represent one literal backslash is that "\" is an escape character in both R strings and for the regex engine to which you're ultimately passing your patterns. If you were talking directly to the regex engine, you'd use "\\" to indicate a literal backslash. But in order to get R to pass "\\" on to the regex engine, you need to type "\\\\".

# %%
# there are some weird cases in some of the comments like
# \\ = =, I wonder why would some one type this. lol
removeWeirdStrings = function(response){
    
    # remove all of the newlines.     
    response = gsub("\\n", "", response)
    
    # this is the main issue here, some comments that ended with //
    # breaks the function of fromJSON, I have to remove them
    response = gsub('\\\\+', '\\\\', response)
    # response = gsub('\\\\', '', response)
    
    # this remove some weird encoding strings...
    response = gsub("\\x[a-z0-9][a-z0-9]", "", response)
    
    response
}

# %%
library(RCurl)
library(rjson)
# Out:
# Loading required package: bitops

# %%
getRecentPost = function(fanpage_id, target_post, access_token){
        
    # get the recent target_post numbers
    all_posts_id_url = sprintf( "https://graph.facebook.com/%s?access_token=%s&fields=posts.limit(%i){id}", fanpage_id, access_token, target_post )
    post_ids = fromJSON(getURL(all_posts_id_url))$posts$data
    print(post_ids)
    print(post_ids[[1]][[1]])
    
    for(j in 1:length(post_ids)){
        
        print(j)
        print(post_ids$id[[j]][[1]])
        # query link
        query_fields = "comments{comments{like_count,message},comment_count,like_count,message},message,scheduled_publish_time,likes"    
        f_url <-sprintf( "https://graph.facebook.com/%s?access_token=%s&fields=%s", post_ids[[j]][[1]], access_token, query_fields )
        print(f_url)
        
        # save the cursor to next post     
        next_post_cursor = ""
        this_post = getURL(f_url)
        this_post_obj = fromJSON(this_post)
        
        # next_post_cursor = this_post_obj$posts$paging["next"][[1]]

        # get all of the commenst of this post first
        if("paging" %in% names(this_post_obj$comments)){
            if ("next" %in% names(this_post_obj$comments$paging)){

                next_cursor = this_post_obj$comments$paging["next"][[1]]
                remaining_comments = list()

                # go into the loop that grasp all of the comments into a large list         
                while(!is.null(next_cursor)){
                    first_layer_comments = getURL(next_cursor)
                    
                    print("WUWUWUWUWUWUWUW")
                    print(first_layer_comments)
                    first_layer_comments = removeWeirdStrings(first_layer_comments)
                    
                    print("POOO?")
                    print(first_layer_comments)
                    next_comments = fromJSON( first_layer_comments, unexpected.escape = "keep")
                    
                    print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
                    print(next_comments)
                    
                    remaining_comments = c(remaining_comments, next_comments$data)
                    next_cursor = next_comments$paging["next"][[1]]
                }

                # print(remaining_comments)
                # append all of them on to the original this_post_obj
                this_post_obj$comments$data = c(this_post_obj$comments$data, remaining_comments)
            }
        }
        

        # print(this_post_obj$posts$data[[1]])

        # get the second layer of comments
        for(i in 1:length(this_post_obj$comments$data)){

            # check if there's paging in the object
            if("paging" %in% names(this_post_obj$comments$data[[i]]$comments)){
                if("next" %in% names(this_post_obj$comments$data[[i]]$comments$paging)){
                    print("this is where we need to run the second layer of comments")

                    next_comments_of_comment = list()
                    cursor_to_coc = this_post_obj$comments$data[[i]]$comments$paging["next"][[1]]

                    while(!is.null(cursor_to_coc)){
                        
                        coc = getURL(cursor_to_coc)
                        coc = removeWeirdStrings(coc)
                        coc = fromJSON( coc, unexpected.escape = "keep")
                        next_comments_of_comment = c(next_comments_of_comment, coc$data)
                        cursor_to_coc = coc$paging["next"][[1]]
                        
                        print("YYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYYY")
                        print(next_comments_of_comment)
                    }

                    # append the long comments of comment to the original this_post_obj
                    this_post_obj$comments$data[[i]]$comments$data = c(this_post_obj$comments$data[[i]]$comments$data, next_comments_of_comment)

                }
            }

        }

        # next_comments_cursor = this_post_obj$posts$data[[1]]$comments$paging["next"][[1]]

        export_json = toJSON(this_post_obj)
        write(export_json, paste( fanpage_id, "-", post_ids[[j]][[1]], ".json", sep=""))
        
        
    }
    
    
}

access_token = "CAACEdEose0cBAJhZAw2fpUcZCkxNJbo7QwAei5xqiJRJs4GZCjoOWNbSp37bRj2MmbZCOUoUoiE8ZAaTIcy9GVBH1DWY6kbU0qvU53qmTz351KUdRlicaa6xsv0n2BV6C6qBIl669lrbReHwMnK3tD25JfnTphKy7tF7WizrB6TVU6Q1ZBhVW3BvnbLUZCRlY3DQB0q6f3iUAZDZD"
one_post = getRecentPost("tsaiingwen", 5, access_token)

# %%
names(one_post)
length(one_post$comments$data)
# Out:
# [1] "message"      "id"           "created_time" "comments"
# [1] 294

# %%
this_post = getURL(f_url)
this_post_obj = fromJSON(this_post)
next_post_cursor = this_post_obj$posts$paging["next"][[1]]
next_cursor = this_post_obj$posts$data[[1]]$comments$paging["next"][[1]]

first_layer_comments = getURL(next_cursor)
next_comments = fromJSON(first_layer_comments)
            
print(next_comments$data)
next_cursor = next_comments$paging["next"][[1]]
# Out:
# [[1]]
# [[1]]$comment_count
# [1] 0
#
# [[1]]$like_count
# [1] 0
#
# [[1]]$message
# [1] "啦啦啦啦啦啦"
#
# [[1]]$id
# [1] "10153141585326065_10153141589776065"
#
#
# [[2]]
# [[2]]$comment_count
# [1] 0
#
# [[2]]$like_count
# [1] 0
#
# [[2]]$message
# [1] "和平共处就看你了蔡英文，"
#
# [[2]]$id
# [1] "10153141585326065_10153141589896065"
#
#
# [[3]]
# [[3]]$comment_count
# [1] 0
#
# [[3]]$like_count
# [1] 3
#
# [[3]]$message
# [1] "為台灣進步加油，為台灣再創奇蹟。"
#
# [[3]]$id
# [1] "10153141585326065_10153141589996065"
#
#
# [[4]]
# [[4]]$comment_count
# [1] 8
#
# [[4]]$like_count
# [1] 39
#
# [[4]]$message
# [1] "終於揮別了無能又腐敗的國冥黨，台灣從此將不再空轉！\n擦乾淚水與汗水，終於能昂首闊步向前行！\n也感謝對岸網友，天天前來洗版\"關心\"！\n貴國的文攻武嚇，只會讓台灣更加團結,堅定信念！\n我們未來會變得更民主更自由，更謙卑更和諧！\n我相信會有開花結果的一天。一起努力！\n\n台灣加油！小英加油！"
#
# [[4]]$id
# [1] "10153141585326065_10153141590001065"
#
# [[4]]$comments
# [[4]]$comments$data
# [[4]]$comments$data[[1]]
# [[4]]$comments$data[[1]]$like_count
# [1] 1
#
# [[4]]$comments$data[[1]]$message
# ...

# %%
sprintf( "https://graph.facebook.com/%s?access_token=%s&fields=posts.limit(%i){id}", "test", "haha", 10 )
# Out:
# [1] "https://graph.facebook.com/test?access_token=haha&fields=posts.limit(10){id}"

# %%
str(paste)
# Out:
# function (..., sep = " ", collapse = NULL)

# %%
sprintf("haha%i", 100 )
# Out:
# [1] "haha100"

# %%
as.integer("10")
# Out:
# [1] 10

# %%
b = getURL("https://graph.facebook.com/v2.5/tsaiingwen?fields=posts.limit(10)%7Bid%7D&access_token=CAACEdEose0cBAMy2zbAOo1z50HLseS1hYmUbmTwW4nrYBZAwWhiQHEbdz0CZCkWpUN4s7xgNzm9SmS4ux9XiQzPexbtJuEHX7XufpWWZAoL1pwg46dXlTXYLaFSPRZCYoZBLHUnUwIZBVXiHBCRGz4WpWqmk5miKVPw7052rwkj4TJgkFmgtxPaXBj8aRoOk4U1xFpDlPQ388R7ZBb3KZBNK")

# %%
b = fromJSON(b)

# %%
b$posts$data[[1]]$id
# Out:
# [1] "46251501064_10153141585326065"

# %%
help(rawToChar)
# Out:
# rawConversion               package:base               R Documentation
#
# s
#
# n:
#
#      Conversion and manipulation of objects of type ‘"raw"’.
#
# e:
#
#      charToRaw(x)
#      rawToChar(x, multiple = FALSE)
#
#      rawShift(x, n)
#
#      rawToBits(x)
#      intToBits(x)
#      packBits(x, type = c("raw", "integer"))
#
# s:
#
#        x: object to be converted or shifted.
#
# multiple: logical: should the conversion be to a single character
#           string or multiple individual characters?
#
#        n: the number of bits to shift.  Positive numbers shift right
#           and negative numbers shift left: allowed values are ‘-8 ...
#           8’.
#
#     type: the result type, partially matched.
#
# s:
#
#      ‘packBits’ accepts raw, integer or logical inputs, the last two
#      without any NAs.
#
#      Note that ‘bytes’ are not necessarily the same as characters, e.g.
#      in UTF-8 locales.
#
# e:
#
# ...

# %%
a = '\\'
str(gsub)
gsub("\\\\","haha" , a)
# Out:
# function (pattern, replacement, x, ignore.case = FALSE, perl = FALSE, fixed = FALSE,
#     useBytes = FALSE)
# [1] "haha"

# %%
library(rjson)
library(jsonlite)
library(RJSONIO)
# Out:
# Attaching package: ‘jsonlite’
#
# The following objects are masked from ‘package:rjson’:
#
#     fromJSON, toJSON
#
# The following object is masked from ‘package:utils’:
#
#     View
#
#
# Attaching package: ‘RJSONIO’
#
# The following objects are masked from ‘package:jsonlite’:
#
#     fromJSON, toJSON
#
# The following objects are masked from ‘package:rjson’:
#
#     fromJSON, toJSON

# %%
test_result = "{\"data\":[{\"comment_count\":0,\"like_count\":0,\"message\":\"╭(╯ε╰)╮受不了，還刪評論，九二共識不動搖誰理你小英在台灣作甚麼妖。台獨，台灣民粹有多少，大陸就返還給妳多少，完全是自己作出來的，管管三立吧！你都選上了，那個攪屎棍就放在一邊吧，拿著很髒的。\",\"id\":\"10153138851281065_10153140019631065\"},{\"comment_count\":0,\"like_count\":0,\"message\":\
TI5dGJXVnVkRjlqZFhKemIzSTZNVEF4TlRNeE5EQXdNVGsyTXpFd05qVTZNVFExTXpjd056RTBOQT09\"},\"previous\":\"https://graph.facebook.com/v2.0/46251501064_10153138851281065/comments?fields=comments%7Blike_count,message%7D,comment_count,like_count,message&limit=25&order=chronological&access_token=CAACEdEose0cBAMy2zbAOo1z50HLseS1hYmUbmTwW4nrYBZAwWhiQHEbdz0CZCkWpUN4s7xgNzm9SmS4ux9XiQzPexbtJuEHX7XufpWWZAoL1pwg46dXlTXYLaFSPRZCYoZBLHUnUwIZBVXiHBCRGz4WpWqmk5miKVPw7052rwkj4TJgkFmgtxPaXBj8aRoOk4U1xFpDlPQ388R7ZBb3KZBNK&before=WTI5dGJXVnVkRjlqZFhKemIzSTZNVEF4TlRNeE5EQXdNVGsyTXpFd05qVTZNVFExTXpjd056RTBOQT09\",\"next\":\"https://graph.facebook.com/v2.0/46251501064_10153138851281065/comments?fields=comments%7Blike_count,message%7D,comment_count,like_count,message&limit=25&after=WTI5dGJXVnVkRjlqZFhKemIzSTZPVGc0TkRjNE1EQTBOVFl3TnpnM09qRTBOVE0zTURneU5qVT0%3D&order=chronological&access_token=CAACEdEose0cBAMy2zbAOo1z50HLseS1hYmUbmTwW4nrYBZAwWhiQHEbdz0CZCkWpUN4s7xgNzm9SmS4ux9XiQzPexbtJuEHX7XufpWWZAoL1pwg46dXlTXYLaFSPRZCYoZBLHUnUwIZBVXiHBCRGz4WpWqmk5miKVPw7052rwkj4TJgkFmgtxPaXBj8aRoOk4U1xFpDlPQ388R7ZBb3KZBNK\"}}"

# %%
test_result = gsub("\\n", "", test_result)
test_result = gsub('\\\\', '', test_result)
test_result = gsub("\\x[a-z1-9][a-z1-9]", "", test_result)
# test_result = gsub('\"', "", test_result)
class(test_result)

rjson::fromJSON(test_result)
print("=========================")
RJSONIO::fromJSON(test_result)
print("=========================")
jsonlite::fromJSON(test_result)
# Out:
# [1] "character"
# $data
# $data[[1]]
# $data[[1]]$comment_count
# [1] 0
#
# $data[[1]]$like_count
# [1] 0
#
# $data[[1]]$message
# [1] "╭(╯ε╰)╮受不了，還刪評論，九二共識不動搖誰理你小英在台灣作甚麼妖。台獨，台灣民粹有多少，大陸就返還給妳多少，完全是自己作出來的，管管三立吧！你都選上了，那個攪屎棍就放在一邊吧，拿著很髒的。"
#
# $data[[1]]$id
# [1] "10153138851281065_10153140019631065"
#
#
# $data[[2]]
# $data[[2]]$comment_count
# [1] 0
#
# $data[[2]]$like_count
# [1] 0
#
# $data[[2]]$message
# [1] "乡愁 • 余光中小时候，When I was young,乡愁是一枚小小的邮票，My homesickness was a small stamp,我在这头，I was here,母亲在那头。My mother was there.长大后，After growing up,乡愁是一张窄窄的船票，My homesickness was a narrow ticket,我在这头，I was here,新娘在那头。My bride was there.后来啊，Later,乡愁是一方矮矮的坟墓，My homesickness was a little tomb,我在外头，I was outside,母亲在里头。My mother was inside.而现在，And now,乡愁是一湾浅浅的海峡，My homesickness is a shallow strait,我在这头，I am here,大陆在那头。The mainland is there.天冷了，湾湾们注意保暖。"
#
# $data[[2]]$id
# [1] "10153138851281065_10153140020041065"
#
#
# $data[[3]]
# $data[[3]]$comment_count
# [1] 0
#
# $data[[3]]$like_count
# ...

# %%
c = "{\"data\":[{\"comment_count\":0,\"like_count\":0,\"message\":\"和平共处就看你了蔡英文，\",\"id\":\"10153141585326065_10153141589896065\"},{\"comment_count\":2,\"like_count\":12,\"message\":\"為台灣進步加油，為台灣再創奇蹟。\",\"id\":\"10153141585326065_10153141589996065\",\"comments\":{\"data\":[{\"like_count\":1,\"message\":\"拭目以待\",\"id\":\"10153141585326065_10153141678821065\"},{\"like_count\":1,\"message\":\"還特麼奇跡，沒了兩蔣以後台灣發生過什麼奇跡\",\"id\":\"10153141585326065_10153141791661065\"}],\"paging\":{\"cursors\":{\"before\":\"WTI5dGJXVnVkRjlqZAFhKemIzSTZANVEF4TlRNeE5ERTJOemc0TWpFd05qVTZANVFExTXpjNU5EYzNNZAz09\",\"after\":\"WTI5dGJXVnVkRjlqZAFhKemIzSTZANVEF4TlRNeE5ERTNPVEUyTmpFd05qVTZANVFExTXpnd01UZAzBNZAz09\"}}}},{\"comment_count\":4946,\"like_count\":446,\"message\":\"終於揮別了無能又腐敗的國冥黨，台灣從此將不再空轉！擦乾淚水與汗水，終於能昂首闊步向前行！也感謝對岸網友，天天前來洗版\"關心\"！貴國的文攻武嚇，只會讓台灣更加團結,堅定信念！我們未來會變得更民主更自由，更謙卑更和諧！我相信會有開花結果的一天。一起努力！台灣加油！小英加油！\",\"id\":\"10153141585326065_10153141590001065\",\"comments\":{\"data\":[{\"like_count\":3,\"message\":\"别太天真了，换个党贪而已。真相信有无私为民服务的人呀？先问问你自己换做是你做不做得到先。傻傻的。。\",\"id\":\"10153141585326065_10153141594891065\"},{\"like_count\":5,\"message\":\"真心為台灣建設，真心以台灣人民為福祉，真心會讓---心與心連結，感動人心，真心也會讓老天爺動容，真心點亮台灣，讓台灣的光，傳遍全世界。\",\"id\":\"10153141585326065_10153141594896065\"},{\"like_count\":5,\"message\":\"好像2000到2008台湾没有空转一样\",\"id\":\"10153141585326065_10153141597716065\"},{\"like_count\":2,\"message\":\"Lee Brad 哈哈哈，神回复\xed\xa0\xbd\xed\xb8\x82\xed\xa0\xbd\xed\xb8\x82\",\"id\":\"10153141585326065_10153141600156065\"},{\"like_count\":0,\"message\":\"哈哈哈，說得好，當初陳水扁下台馬英九上台時也是這個調調，好強烈的既視感\",\"id\":\"10153141585326065_10153141600756065\"},{\"like_count\":0,\"message\":\"咦，好熟悉的句子。扁仔卸任你们也是这么说的吧？从小蔡那看似坚决实则毫无城府的表现来看，她实在算不上一个优秀的政治家。不看好台湾未来4年的前景。\",\"id\":\"10153141585326065_10153141602161065\"},{\"like_count\":1,\"message\":\"哦\",\"id\":\"10153141585326065_10153141602876065\"},{\"like_count\":1,\"message\":\"蔡總統，南海太平島妳一定要有作為
金的意思是有錢的就可以包裝下和自己關係好的，讓他當政幫自己弄點好處沒錢的哪凉快哪呆著去麼？\",\"id\":\"10153141585326065_755496017918489\"},{\"like_count\":0,\"message\":\"能告诉我蔡英文那俩亿怎么回事，陈水扁的往家里背钱是怎么回事，貌似蔡英文那俩亿还是陈水扁儿子给的，是不是让蔡英文上台放他老爸啊？\",\"id\":\"10153141585326065_755499414584816\"},{\"like_count\":5,\"message\":\"張彤恩 如果你们不想当中国人，可以移民，我们不阻挡，这是你的自由。但是台湾岛是祖宗给我们留下的，人走岛留。谁要想把台湾从中国分裂出去，我们就扭断他的脖子。不信，你可以请缨蔡英文，让他宣布台湾独立试一试。\",\"id\":\"10153141585326065_755507031250721\"},{\"like_count\":6,\"message\":\"劉先生我是台灣人，是你想移民吧!\",\"id\":\"10153141585326065_10153141766766065\"},{\"like_count\":3,\"message\":\"先把高级外省人接回中国。其他一切好谈。以后各奔东西。井水不犯河水，中国是中国，台湾是台湾\",\"id\":\"10153141585326065_10153141772746065\"},{\"like_count\":0,\"message\":\"馬關條約是有效的 它符合國際法中的雙邊條約 包括中國的外東北個讓給俄羅斯也是通過璦輝條約以及北京的條約給割讓的 這些都是國際法的常識就算是中國真是民主社會 台灣也不可能回歸 否則台灣在國際經濟領域會越來越邊緣化 只會讓北京越來越肥 只有獨立 台灣才能實現持續的繁榮 否則台灣會成為下一個香港台灣真的不是中國的領土 如果非要武力威脅 請你維基百科《美國與台灣關係法》台灣人不怕共匪的威脅!!!\",\"id\":\"10153141585326065_755508337917257\"}],\"paging\":{\"cursors\":{\"before\":\"WTI5dGJXVnVkRjlqZAFhKemIzSTZANVEF4TlRNeE5ERTFPVGMxTmpFd05qVTZANVFExTXpjNE9EY3dPQT09\",\"after\":\"WTI5dGJXVnVkRjlqZAFhKemIzSTZAOelUxTlRBNE16TTNPVEUzTWpVM09qRTBOVE00TURBeU5EYz0ZD\"},\"next\":\"https://graph.facebook.com/v2.0/10153141585326065_10153141591316065/comments?access_token=CAACEdEose0cBAJhZAw2fpUcZCkxNJbo7QwAei5xqiJRJs4GZCjoOWNbSp37bRj2MmbZCOUoUoiE8ZAaTIcy9GVBH1DWY6kbU0qvU53qmTz351KUdRlicaa6xsv0n2BV6C6qBIl669lrbReHwMnK3tD25JfnTphKy7tF7WizrB6TVU6Q1ZBhVW3BvnbLUZCRlY3DQB0q6f3iUAZDZD&fields=like_count%2Cmessage&limit=25&after=WTI5dGJXVnVkRjlqZAFhKemIzSTZAOelUxTlRBNE16TTNPVEUzTWpVM09qRTBOVE00TURBeU5EYz0ZD\"}}},{\"comment_count\":0,\"like_count\":0,\"message\":\"亲天冷了要多穿衣哦\",\"id\":\"10153141585326065_10153141591341065\"},{\"comment_count\":0,\"like_count\":6,\"message\":\"先把鄭運鵬處理一下吧⋯⋯不然都是廢話！\",\"id\":\"10153141585326065_10153141591381065\"},{\"comment_count\":1,\"like_count\":2,\"message\":\"要不要讓鄭大立委加入車輪黨\",\"id\":\"10153141585326065_10153141591826065\",\"comments\":{\"data\":[{\"like_count\":1,\"message\":\"沈富雄大老已退，請讓事件落幕，感謝！\",\"id\":\"10153141585326065_10153141601231065\"}],\"paging\":{\"cursors\":{\"before\":\"WTI5dGJXVnVkRjlqZAFhKemIzSTZANVEF4TlRNeE5ERTJ
\"id\":\"10153141585326065_10153142129711065\"},{\"like_count\":0,\"message\":\"民主進步蔡總統。有愛臺灣有能力。有責任感有誠信。開創寶島新臺灣。\",\"id\":\"10153141585326065_10153142257036065\"},{\"like_count\":0,\"message\":\"湾湾们加我qq:301477150,加我微信:zl381477150,我们就是好友啦\",\"id\":\"10153141585326065_10153142512011065\"}],\"paging\":{\"cursors\":{\"before\":\"WTI5dGJXVnVkRjlqZAFhKemIzSTZANVEF4TlRNeE5ERTFPVFF3TXpZAd05qVTZANVFExTXpjNE9EUTJPQT09\",\"after\":\"WTI5dGJXVnVkRjlqZAFhKemIzSTZANVEF4TlRNeE5ESTFNVEl3TVRFd05qVTZANVFExTXpnek5qSTJNQT09\"}}}}],\"paging\":{\"cursors\":{\"after\":\"WTI5dGJXVnVkRjlqZFhKemIzSTZNVEF4TlRNeE5ERTFPVE14T0RFd05qVTZNVFExTXpjNE9ETTVNUT09\",\"before\":\"WTI5dGJXVnVkRjlqZFhKemIzSTZNVEF4TlRNeE5ERTFPRGs0T1RZd05qVTZNVFExTXpjNE9ESXdNdz09\"},\"previous\":\"https://graph.facebook.com/v2.0/46251501064_10153141585326065/comments?fields=comments%7Blike_count,message%7D,comment_count,like_count,message&limit=25&order=chronological&access_token=CAACEdEose0cBAJhZAw2fpUcZCkxNJbo7QwAei5xqiJRJs4GZCjoOWNbSp37bRj2MmbZCOUoUoiE8ZAaTIcy9GVBH1DWY6kbU0qvU53qmTz351KUdRlicaa6xsv0n2BV6C6qBIl669lrbReHwMnK3tD25JfnTphKy7tF7WizrB6TVU6Q1ZBhVW3BvnbLUZCRlY3DQB0q6f3iUAZDZD&before=WTI5dGJXVnVkRjlqZFhKemIzSTZNVEF4TlRNeE5ERTFPRGs0T1RZd05qVTZNVFExTXpjNE9ESXdNdz09\",\"next\":\"https://graph.facebook.com/v2.0/46251501064_10153141585326065/comments?fields=comments%7Blike_count,message%7D,comment_count,like_count,message&limit=25&after=WTI5dGJXVnVkRjlqZFhKemIzSTZNVEF4TlRNeE5ERTFPVE14T0RFd05qVTZNVFExTXpjNE9ETTVNUT09&order=chronological&access_token=CAACEdEose0cBAJhZAw2fpUcZCkxNJbo7QwAei5xqiJRJs4GZCjoOWNbSp37bRj2MmbZCOUoUoiE8ZAaTIcy9GVBH1DWY6kbU0qvU53qmTz351KUdRlicaa6xsv0n2BV6C6qBIl669lrbReHwMnK3tD25JfnTphKy7tF7WizrB6TVU6Q1ZBhVW3BvnbLUZCRlY3DQB0q6f3iUAZDZD\"}}"

# %%
b = gsub('\\\\+"', '\\\\"', c)
b
fromJSON(b)
# Out:
# Warning message:
# In grep("'", string): 輸入的字串 1 不適用於此語言環境Warning message:
# In grep("'", string): 輸入的字串 1 不適用於此語言環境Warning message:
# In grep("'", string): 輸入的字串 1 不適用於此語言環境
# ...

# %%
z = '\\\\"'
z
# str(grep)
gsub('\\\\+', "\\\\", z)

str(grep)
str(gsub)
# Out:
# [1] "\\\\\""
# [1] "\\"
# [1] "\\\""
# function (pattern, x, ignore.case = FALSE, perl = FALSE, value = FALSE,
#     fixed = FALSE, useBytes = FALSE, invert = FALSE)
# function (pattern, replacement, x, ignore.case = FALSE, perl = FALSE, fixed = FALSE,
#     useBytes = FALSE)
